# %%
import pandas as pd

df = pd.read_csv('isic-2024-challenge/train-metadata.csv')
print(df['target'].value_counts())
# Out:
# C:\Users\lsj\AppData\Local\Temp\ipykernel_8544\3030715946.py:3: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('isic-2024-challenge/train-metadata.csv')
# target
# 0    400666
# 1       393
# Name: count, dtype: int64

# %%
import timm

pretrained_models = timm.list_models(pretrained=True)
efficientnet_models = timm.list_models('*efficientnet*')

pretrained_efficientnet_models = [model for model in pretrained_models if 'efficientnetv2' in model]
print(timm.list_models())
print(efficientnet_models)
print(pretrained_models)
print(pretrained_efficientnet_models)
# Out:
# ['bat_resnext26ts', 'beit_base_patch16_224', 'beit_base_patch16_384', 'beit_large_patch16_224', 'beit_large_patch16_384', 'beit_large_patch16_512', 'beitv2_base_patch16_224', 'beitv2_large_patch16_224', 'botnet26t_256', 'botnet50ts_256', 'caformer_b36', 'caformer_m36', 'caformer_s18', 'caformer_s36', 'cait_m36_384', 'cait_m48_448', 'cait_s24_224', 'cait_s24_384', 'cait_s36_384', 'cait_xs24_384', 'cait_xxs24_224', 'cait_xxs24_384', 'cait_xxs36_224', 'cait_xxs36_384', 'coat_lite_medium', 'coat_lite_medium_384', 'coat_lite_mini', 'coat_lite_small', 'coat_lite_tiny', 'coat_mini', 'coat_small', 'coat_tiny', 'coatnet_0_224', 'coatnet_0_rw_224', 'coatnet_1_224', 'coatnet_1_rw_224', 'coatnet_2_224', 'coatnet_2_rw_224', 'coatnet_3_224', 'coatnet_3_rw_224', 'coatnet_4_224', 'coatnet_5_224', 'coatnet_bn_0_rw_224', 'coatnet_nano_cc_224', 'coatnet_nano_rw_224', 'coatnet_pico_rw_224', 'coatnet_rmlp_0_rw_224', 'coatnet_rmlp_1_rw2_224', 'coatnet_rmlp_1_rw_224', 'coatnet_rmlp_2_rw_224', 'coatnet_rmlp
# ...

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df = pd.read_csv('isic-2024-challenge/train-metadata.csv')
df.info()
# Out:
# C:\Users\lsj\AppData\Local\Temp\ipykernel_7760\765206505.py:5: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('isic-2024-challenge/train-metadata.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401059 entries, 0 to 401058
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   isic_id                       401059 non-null  object
#  1   target                        401059 non-null  int64
#  2   patient_id                    401059 non-null  object
#  3   age_approx                    398261 non-null  float64
#  4   sex                           389542 non-null  object
#  5   anatom_site_general           395303 non-null  object
#  6   clin_size_long_diam_mm        401059 non-null  float64
#  7   image_type                    401059 non-null  object
# ...

# %%
condition = (df['age_approx'].notnull()) & (df['sex'].notnull()) & (df['target'] == 1)
print(len(df[condition]))
# Out:
# 381

# %%
import os 

#os.chdir('..')
print(os.getcwd())
# Out:
# c:\Users\lsj\Desktop

# %%
import sys

sys.path.append(os.getcwd())

# %%
from codes.preprocess import num_cols, cat_cols

os.chdir(os.getcwd()+'/YB/TBP')
print(len(num_cols)+len(cat_cols))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from codes.preprocess import num_cols, cat_cols
#       3 os.chdir(os.getcwd()+'/YB/TBP')
#       4 print(len(num_cols)+len(cat_cols))
#
# ModuleNotFoundError: No module named 'codes'
